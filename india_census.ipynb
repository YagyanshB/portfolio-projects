# %% [markdown]
# <a href="https://colab.research.google.com/github/YagyanshB/portfolio-projects/blob/main/india_census.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Description:
#
# The dataset we would be exploring contains information about **Population, Demography, Literacy, States, Workers, Religion, Education and Age** of the citizens of **India**.
#
# The dataset is from a census carried out in the year **2011**.

# %% [markdown]
# # Importing Required Libraries:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Uploading & Investigating our Dataset:

# %%
df = pd.read_csv('file.csv')

# %%
# Inspecting the first few rows

df.head(5)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
# Investigating the shape of our dataset

df.shape

print(f'The dataset has {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
# The dataset has 640 rows and 25 columns.

# %%
df.isnull().sum()
# Out:
# District_code           0
# State_name              0
# District_name           0
# Population              0
# Male                    0
# Female                  0
# Literate                0
# Workers                 0
# Male_Workers            0
# Female_Workers          0
# Cultivator_Workers      0
# Agricultural_Workers    0
# Household_Workers       0
# Hindus                  0
# Muslims                 0
# Christians              0
# Sikhs                   0
# Buddhists               0
# Jains                   0
# Secondary_Education     0
# Higher_Education        0
# Graduate_Education      0
# Age_Group_0_29          0
# Age_Group_30_49         0
# Age_Group_50            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# District_code            int64
# State_name              object
# District_name           object
# Population               int64
# Male                     int64
# Female                   int64
# Literate                 int64
# Workers                  int64
# Male_Workers             int64
# Female_Workers           int64
# Cultivator_Workers       int64
# Agricultural_Workers     int64
# Household_Workers        int64
# Hindus                   int64
# Muslims                  int64
# Christians               int64
# Sikhs                    int64
# Buddhists                int64
# Jains                    int64
# Secondary_Education      int64
# Higher_Education         int64
# Graduate_Education       int64
# Age_Group_0_29           int64
# Age_Group_30_49          int64
# Age_Group_50             int64
# dtype: object

# %%
df.describe()
# Out:
#        District_code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#             Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# count  6.400000e+02  6.400000e+02    6.400000e+02        6.400000e+02
# mean   7.529514e+05  5.186561e+05    2.342953e+05        1.856387e+05
# ...

# %%
# Segregating our dataset based on States showcases that the information we have
# would be slightly biased given certain states reflect a greater deal of information
# than the other states

# for example Uttar Pradesh has a count of 71 in comparison to West Benagl's 19

df['State_name'].value_counts()
# Out:
# State_name
# UTTAR PRADESH                  71
# MADHYA PRADESH                 50
# BIHAR                          38
# MAHARASHTRA                    35
# RAJASTHAN                      33
# TAMIL NADU                     32
# KARNATAKA                      30
# ORISSA                         30
# ASSAM                          27
# GUJARAT                        26
# JHARKHAND                      24
# ANDHRA PRADESH                 23
# JAMMU AND KASHMIR              22
# HARYANA                        21
# PUNJAB                         20
# WEST BENGAL                    19
# CHHATTISGARH                   18
# ARUNACHAL PRADESH              16
# KERALA                         14
# UTTARAKHAND                    13
# HIMACHAL PRADESH               12
# NAGALAND                       11
# MANIPUR                         9
# NCT OF DELHI                    9
# MIZORAM                         8
# MEGHALAYA                       7
# TRIPURA                         4
# ...

# %% [markdown]
# # Data Manipulation & Transformation:

# %%
# Hiding indexes of our dataframe or datasets would prevent unintended joins or merges

# %%
styled_df = df.style.hide(axis="index").set_caption('India Census 2011')
display(styled_df)

# If you need to access the original DataFrame, use 'df'
df.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_13fb2" class="dataframe">
#   <caption>India Census 2011</caption>
#   <thead>
#     <tr>
#       <th id="T_13fb2_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_13fb2_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_13fb2_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_13fb2_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_13fb2_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_13fb2_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_13fb2_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_13fb2_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_13fb2_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
#       <th id="T_13fb2_level0_col9" class="col_heading level0 col9" >Female_Workers</th>
# ...

# %%
df.head(5)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df[df['District_name'].isin(['New Delhi', 'Jaipur', 'Lucknow'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %%
# Calculate state wise total population

df.groupby('State_name')['Population'].sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       380581
# ANDHRA PRADESH                  84580777
# ARUNACHAL PRADESH                1383727
# ASSAM                           31205576
# BIHAR                          104099452
# CHANDIGARH                       1055450
# CHHATTISGARH                    25545198
# DADRA AND NAGAR HAVELI            343709
# DAMAN AND DIU                     243247
# GOA                              1458545
# GUJARAT                         60439692
# HARYANA                         25351462
# HIMACHAL PRADESH                 6864602
# JAMMU AND KASHMIR               12541302
# JHARKHAND                       32988134
# KARNATAKA                       61095297
# KERALA                          33406061
# LAKSHADWEEP                        64473
# MADHYA PRADESH                  72626809
# MAHARASHTRA                    112374333
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# ...

# %%
df.groupby('State_name')[['Hindus', 'Sikhs', 'Muslims', 'Christians', 'Jains', 'Buddhists']].sum().sort_values(by='Hindus', ascending=False)
# Out:
#                                 Hindus     Sikhs   Muslims  Christians  \
# State_name
# UTTAR PRADESH                159312654    643500  38483967      356448
# MAHARASHTRA                   89703057    223247  12971152     1080073
# BIHAR                         86078686     23779  17557809      129247
# ANDHRA PRADESH                74824149     40244   8082412     1129784
# MADHYA PRADESH                66007121    151412   4774695      213282
# WEST BENGAL                   64385546     63523  24654825      658618
# TAMIL NADU                    63188168     14601   4229479     4418331
# RAJASTHAN                     60657103    872930   6215377       96430
# GUJARAT                       53533988     58246   5846761      316178
# KARNATAKA                     51317472     28773   7893065     1142647
# ORISSA                        39300341     21991    911670     1161708
# CHHATTISGARH                  23819789     70036    514998      490542
# ...

# %%
df.head(5)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df[df['State_name'] == 'MAHARASHTRA']['Male_Workers'].sum()
# Out:
# 32616875

# %%
df.groupby('State_name')[['Male_Workers', 'Female_Workers']].sum()
# Out:
#                              Male_Workers  Female_Workers
# State_name
# ANDAMAN AND NICOBAR ISLANDS        120889           31646
# ANDHRA PRADESH                   24185595        15237311
# ARUNACHAL PRADESH                  350273          237384
# ASSAM                             8541560         3428130
# BIHAR                            25222189         9502798
# CHANDIGARH                         328159           75977
# CHHATTISGARH                      7133866         5046359
# DADRA AND NAGAR HAVELI             119293           37868
# DAMAN AND DIU                      107434           13837
# GOA                                419536          157712
# GUJARAT                          18000914         6766833
# HARYANA                           6806636         2109872
# HIMACHAL PRADESH                  2043373         1516049
# JAMMU AND KASHMIR                 3195090         1127623
# JHARKHAND                         8424769         4673505
# ...

# %%
df.dtypes
# Out:
# District_code            int64
# State_name              object
# District_name           object
# Population               int64
# Male                     int64
# Female                   int64
# Literate                 int64
# Workers                  int64
# Male_Workers             int64
# Female_Workers           int64
# Cultivator_Workers       int64
# Agricultural_Workers     int64
# Household_Workers        int64
# Hindus                   int64
# Muslims                  int64
# Christians               int64
# Sikhs                    int64
# Buddhists                int64
# Jains                    int64
# Secondary_Education      int64
# Higher_Education         int64
# Graduate_Education       int64
# Age_Group_0_29           int64
# Age_Group_30_49          int64
# Age_Group_50             int64
# dtype: object

# %%
df = df.set_index('State_name')

# %%
df.head(5)
# Out:
#                    District_code District_name  Population    Male  Female  \
# State_name
# JAMMU AND KASHMIR              1       Kupwara      870354  474190  396164
# JAMMU AND KASHMIR              2        Badgam      753745  398041  355704
# JAMMU AND KASHMIR              3   Leh(Ladakh)      133487   78971   54516
# JAMMU AND KASHMIR              4        Kargil      140802   77785   63017
# JAMMU AND KASHMIR              5         Punch      476835  251899  224936
#
#                    Literate  Workers  Male_Workers  Female_Workers  \
# State_name
# JAMMU AND KASHMIR    439654   229064        190899           38165
# JAMMU AND KASHMIR    335649   214866        162578           52288
# JAMMU AND KASHMIR     93770    75079         53265           21814
# JAMMU AND KASHMIR     86236    51873         39839           12034
# JAMMU AND KASHMIR    261724   161393        117677           43716
#
#                    Cultivator_Workers  ...  Christians  Sikhs  Buddhists  \
# ...
